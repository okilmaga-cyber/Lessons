# %% [markdown]
# <a href="https://colab.research.google.com/github/okilmaga-cyber/Lessons/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Untitled10_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

np.random.seed(42)

fighter_red  = ["Conor McGregor", "Khabib Nurmagomedov", "Israel Adesanya","Islam Mahachev","Makc Hollowey"]
fighter_blue = ["Dustin Poirier", "Justin Gaethje", "Marvin Vettori","Ian Gerriy","Charles Oliveira"]
data         = ["2021-01-23", "2020-10-24", "2021-06-12","2026-08-15","2026-03-07"]
winners      = ["Dustin Poirier", "Khabib Nurmagomedov", "Israel Adesanya","Islam Mahachev","Charles Oliveira"]


red_total_strikes = ["92","80","208","114","92"]
red_sig_strikes   = ["66","80","181","44","45"]
red_takedowns     = ["0","3","0", "15","0"]
red_Nakedown = ["0","0","0","1","0"]

blue_total_strikes = ["98","46","211","141","137"]
blue_sig_strikes   = ["91","45","176","65","66"]
blue_takedowns     = ["1", "0","14","0","13"]
blue_Nakedown = ["1","0","0","0","0"]

df = pd.DataFrame({
    "A_fighter": fighter_red,
    "B_fighter": fighter_blue,
    "Date": data,
    "Winner": winners,
    "red_total_strikes": red_sig_strikes,
    "blue_total_strikes": blue_total_strikes,
    "red_sig_strikes": red_sig_strikes,
    "blue_sig_strikes": blue_sig_strikes,
    "red_takedowns": red_takedowns,
    "blue_takedowns": blue_takedowns,
    "red_Nakedown":red_Nakedown,
    "blue_Nakedown":blue_Nakedown,
})

df.head()
# Out:
#              A_fighter         B_fighter        Date               Winner  \
# 0       Conor McGregor    Dustin Poirier  2021-01-23       Dustin Poirier
# 1  Khabib Nurmagomedov    Justin Gaethje  2020-10-24  Khabib Nurmagomedov
# 2      Israel Adesanya    Marvin Vettori  2021-06-12      Israel Adesanya
# 3       Islam Mahachev        Ian Gerriy  2026-08-15       Islam Mahachev
# 4        Makc Hollowey  Charles Oliveira  2026-03-07     Charles Oliveira
#
#   red_total_strikes blue_total_strikes red_sig_strikes blue_sig_strikes  \
# 0                66                 98              66               91
# 1                80                 46              80               45
# 2               181                211             181              176
# 3                44                141              44               65
# 4                45                137              45               66
#
#   red_takedowns blue_takedowns red_Nakedown blue_Nakedown
# ...
